# %% [markdown]
# # Peer-graded Assignment: Concrete Compressive Strength Prediction
# **Student:** Luis Ignacio Reyes Castro

# %% [markdown]
# ### Assignment Topic
# In this project, we will build a regression model using the Keras library to model the same data about concrete compressive strength that we used in Lab 3.
#
# For your convenience, the data can be found here again:
# [https://cocl.us/concrete_data](https://cocl.us/concrete_data). To recap, the predictors in the data of concrete strength include:
# * Cement
# * Blast Furnace Slag
# * Fly Ash
# * Water
# * Superplasticizer
# * Coarse Aggregate
# * Fine Aggregate

# %% [markdown]
# Let's start by installing and importing the required libraries.

# %%
print( '-' * 72 )
print( 'BEGIN INSTALLATION OF REQUIRED LIBRARIES' )
print( '-' * 72 )
# !pip install numpy==2.0.2
# !pip install pandas==2.2.2
# !pip install tensorflow_cpu==2.18.0
# !pip install scikit-learn==1.6.0
# !pip install matplotlib==3.9.3
print( '-' * 72 )
print( 'INSTALLATION OF REQUIRED LIBRARIES COMPLETE' )
print( '-' * 72 )
# Out:
# ------------------------------------------------------------------------
# BEGIN INSTALLATION OF REQUIRED LIBRARIES
# ------------------------------------------------------------------------
# Requirement already satisfied: numpy==2.0.2 in /opt/conda/lib/python3.12/site-packages (2.0.2)
# Requirement already satisfied: pandas==2.2.2 in /opt/conda/lib/python3.12/site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /opt/conda/lib/python3.12/site-packages (from pandas==2.2.2) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.12/site-packages (from pandas==2.2.2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.12/site-packages (from pandas==2.2.2) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.12/site-packages (from pandas==2.2.2) (2025.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas==2.2.2) (1.17.0)
# Requirement already satisfied: tensorflow_cpu==2.18.0 in /opt/conda/lib/python3.12/site-packages (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in /opt/conda/lib/python3.12/site-packages (from tensorflow_cpu==2.18.0) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/conda/lib/python3.12/site-packages (from tensorflow_cpu==2.18.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /opt/conda/lib/python3.12/site-packages (from tensorflow_cpu==2.18.0) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /opt/conda/lib/python3.12/site-packages (from tensorflow_cpu==2.18.0) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/conda/lib/python3.12/site-packages (from tensorflow_cpu==2.18.0) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /opt/conda/lib/python3.12/site-packages (from tensorflow_cpu==2.18.0) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/conda/lib/python3.12/site-packages (from tensorflow_cpu==2.18.0) (3.4.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.12/site-packages (from tensorflow_cpu==2.18.0) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /opt/conda/lib/python3.12/site-packages (from tensorflow_cpu==2.18.0) (5.29.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/conda/lib/python3.12/site-packages (from tensorflow_cpu==2.18.0) (2.32.3)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.12/site-packages (from tensorflow_cpu==2.18.0) (75.8.0)
# Requirement already satisfied: six>=1.12.0 in /opt/conda/lib/python3.12/site-packages (from tensorflow_cpu==2.18.0) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/conda/lib/python3.12/site-packages (from tensorflow_cpu==2.18.0) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/conda/lib/python3.12/site-packages (from tensorflow_cpu==2.18.0) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /opt/conda/lib/python3.12/site-packages (from tensorflow_cpu==2.18.0) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/conda/lib/python3.12/site-packages (from tensorflow_cpu==2.18.0) (1.70.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /opt/conda/lib/python3.12/site-packages (from tensorflow_cpu==2.18.0) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /opt/conda/lib/python3.12/site-packages (from tensorflow_cpu==2.18.0) (3.8.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in /opt/conda/lib/python3.12/site-packages (from tensorflow_cpu==2.18.0) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /opt/conda/lib/python3.12/site-packages (from tensorflow_cpu==2.18.0) (3.13.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /opt/conda/lib/python3.12/site-packages (from tensorflow_cpu==2.18.0) (0.4.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/conda/lib/python3.12/site-packages (from astunparse>=1.6.0->tensorflow_cpu==2.18.0) (0.45.1)
# Requirement already satisfied: rich in /opt/conda/lib/python3.12/site-packages (from keras>=3.5.0->tensorflow_cpu==2.18.0) (13.9.4)
# Requirement already satisfied: namex in /opt/conda/lib/python3.12/site-packages (from keras>=3.5.0->tensorflow_cpu==2.18.0) (0.0.8)
# Requirement already satisfied: optree in /opt/conda/lib/python3.12/site-packages (from keras>=3.5.0->tensorflow_cpu==2.18.0) (0.14.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow_cpu==2.18.0) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow_cpu==2.18.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow_cpu==2.18.0) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow_cpu==2.18.0) (2024.12.14)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/lib/python3.12/site-packages (from tensorboard<2.19,>=2.18->tensorflow_cpu==2.18.0) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/conda/lib/python3.12/site-packages (from tensorboard<2.19,>=2.18->tensorflow_cpu==2.18.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/conda/lib/python3.12/site-packages (from tensorboard<2.19,>=2.18->tensorflow_cpu==2.18.0) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow_cpu==2.18.0) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.12/site-packages (from rich->keras>=3.5.0->tensorflow_cpu==2.18.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.12/site-packages (from rich->keras>=3.5.0->tensorflow_cpu==2.18.0) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow_cpu==2.18.0) (0.1.2)
# Requirement already satisfied: scikit-learn==1.6.0 in /opt/conda/lib/python3.12/site-packages (1.6.0)
# Requirement already satisfied: numpy>=1.19.5 in /opt/conda/lib/python3.12/site-packages (from scikit-learn==1.6.0) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /opt/conda/lib/python3.12/site-packages (from scikit-learn==1.6.0) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in /opt/conda/lib/python3.12/site-packages (from scikit-learn==1.6.0) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/conda/lib/python3.12/site-packages (from scikit-learn==1.6.0) (3.5.0)
# Requirement already satisfied: matplotlib==3.9.3 in /opt/conda/lib/python3.12/site-packages (3.9.3)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib==3.9.3) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.12/site-packages (from matplotlib==3.9.3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.12/site-packages (from matplotlib==3.9.3) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib==3.9.3) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /opt/conda/lib/python3.12/site-packages (from matplotlib==3.9.3) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.12/site-packages (from matplotlib==3.9.3) (24.2)
# Requirement already satisfied: pillow>=8 in /opt/conda/lib/python3.12/site-packages (from matplotlib==3.9.3) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib==3.9.3) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.12/site-packages (from matplotlib==3.9.3) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib==3.9.3) (1.17.0)
# ------------------------------------------------------------------------
# INSTALLATION OF REQUIRED LIBRARIES COMPLETE
# ------------------------------------------------------------------------

# %%
import pandas as pd
import numpy as np
import random

import keras
from keras.models import Sequential
from keras.layers import Input
from keras.layers import Dense

import sklearn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error

import warnings
warnings.simplefilter('ignore', FutureWarning)
# Out:
# 2025-02-26 02:00:34.362489: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-02-26 02:00:34.433206: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# Flake8 is very annoying. The following lines mute the most common warning.

# %%
# !echo "[flake8]" > ~/.config/flake8
# !echo "ignore = E303" >> ~/.config/flake8

# %% [markdown]
# Next we set random number generator seeds for reproducibility.

# %%
lucky_number = 42
random.seed(lucky_number)
np.random.seed(lucky_number)
keras.utils.set_random_seed(lucky_number)

# %% [markdown]
# Now let's download the data and load it into a pandas dataframe.

# %%
filepath='https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0101EN/labs/data/concrete_data.csv'
concrete_data = pd.read_csv(filepath)
concrete_data.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %% [markdown]
# As instructed, we will be using the first seven columns as predictors.

# %%
n_cols     = 7
predictors = concrete_data.iloc[ :, :n_cols]
target     = concrete_data['Strength']
X = predictors.to_numpy()
y = target.to_numpy()

# %% [markdown]
# Finally, we define the function in charge of the train-test split.

# %%
def split_data( test_size) :
    X_train, X_test, y_train, y_test = \
    train_test_split( X, y, test_size = test_size)
    return X_train, X_test, y_train, y_test

# %% [markdown]
# ## Part A: Build a Baseline Model

# %% [markdown]
# As instructed, we build a neural network model with the following specifications:
# - One hidden layer with 10 nodes with ReLU activations.
# - Optimizer: Adam (short for Adaptive Momentum)
# - Loss: Mean Squared Error

# %%
# Define neural network model
def regression_model() :
    model = Sequential()
    model.add( Input( shape = (n_cols,)) )
    model.add( Dense( 10, activation = 'relu') )
    model.add( Dense(1) )
    model.compile( optimizer = 'adam', loss = 'mean_squared_error')
    return model

# %% [markdown]
# Now we repeat 50 times the following activities:
# 1. Randomly split the data into a training and test sets by holding 30% of the data for testing.
# 2. Train the model on the training data using 50 epochs.
# 3. Evaluate the model on the test data and compute the mean squared error between the predicted concrete strength and the actual concrete strength.

# %%
# Initialize number of iterations and MSEs placeholder
iterations = 50
mses       = np.zeros((iterations,))
# Iterate...
for i in range(iterations) :
    print(f'ITERATION {i}:')
    # Split data into training and test sets
    X_train, X_test, y_train, y_test = split_data( test_size = 0.30)
    # Build and train neural network model
    model = regression_model()
    model.fit( X_train, y_train, epochs = 50, verbose = 0)
    # Compute the Mean Squared Error (MSE)
    mses[i] = model.evaluate( X_test, y_test)
    print(f'Test Data Mean Squared Error: {mses[i]:.2f}')
# Compute and report the mean and std of the MSEs
print('ITERATIONS COMPLETE')
mses_mean = mses.mean()
mses_std  = mses.std()
print('Test Data Statistics:')
print(f'- Mean of the MSEs: {mses_mean:.2f}')
print(f'- Standard Deviation of the MSEs: {mses_std:.2f}')
# Out:
# ITERATION 0:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 177.4348
# Test Data Mean Squared Error: 175.16
# ITERATION 1:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 285.6011
# Test Data Mean Squared Error: 301.09
# ITERATION 2:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 230.8200
# Test Data Mean Squared Error: 239.50
# ITERATION 3:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1914.8876
# Test Data Mean Squared Error: 1960.17
# ITERATION 4:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 165.0546
# Test Data Mean Squared Error: 151.50
# ITERATION 5:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 902.4086
# Test Data Mean Squared Error: 1048.47
# ITERATION 6:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 163.6655
# Test Data Mean Squared Error: 167.65
# ITERATION 7:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 254.2350
# Test Data Mean Squared Error: 233.94
# ITERATION 8:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 164.2866
# Test Data Mean Squared Error: 158.91
# ITERATION 9:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2538.1045
# Test Data Mean Squared Error: 2507.98
# ITERATION 10:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 638.1736
# Test Data Mean Squared Error: 674.58
# ITERATION 11:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 571.3824
# Test Data Mean Squared Error: 566.27
# ITERATION 12:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 254.0992
# Test Data Mean Squared Error: 244.53
# ITERATION 13:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 392.7850
# Test Data Mean Squared Error: 387.64
# ITERATION 14:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 366.7961
# Test Data Mean Squared Error: 365.56
# ITERATION 15:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 504.3029
# Test Data Mean Squared Error: 472.37
# ITERATION 16:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 266.9632
# Test Data Mean Squared Error: 285.40
# ITERATION 17:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 719.0035
# Test Data Mean Squared Error: 740.21
# ITERATION 18:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 219.4957
# Test Data Mean Squared Error: 220.92
# ITERATION 19:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 327.3364
# Test Data Mean Squared Error: 323.77
# ITERATION 20:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1754.7721
# Test Data Mean Squared Error: 1683.59
# ITERATION 21:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 138.7931
# Test Data Mean Squared Error: 145.50
# ITERATION 22:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 274.3891
# Test Data Mean Squared Error: 262.90
# ITERATION 23:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2065.9050
# Test Data Mean Squared Error: 2051.72
# ITERATION 24:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 184.9005
# Test Data Mean Squared Error: 176.72
# ITERATION 25:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 289.0081
# Test Data Mean Squared Error: 308.05
# ITERATION 26:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 503.0348
# Test Data Mean Squared Error: 527.55
# ITERATION 27:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 268.0316
# Test Data Mean Squared Error: 256.52
# ITERATION 28:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2932.1948
# Test Data Mean Squared Error: 2782.83
# ITERATION 29:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 223.2293
# Test Data Mean Squared Error: 233.42
# ITERATION 30:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 175.9731
# Test Data Mean Squared Error: 178.33
# ITERATION 31:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 245.8671
# Test Data Mean Squared Error: 242.09
# ITERATION 32:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 136.1729
# Test Data Mean Squared Error: 151.45
# ITERATION 33:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 337.3383
# Test Data Mean Squared Error: 368.85
# ITERATION 34:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 189.0241
# Test Data Mean Squared Error: 187.66
# ITERATION 35:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 300.0112
# Test Data Mean Squared Error: 287.16
# ITERATION 36:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 249.6281
# Test Data Mean Squared Error: 248.37
# ITERATION 37:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 389.3029
# Test Data Mean Squared Error: 384.55
# ITERATION 38:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 144.7731
# Test Data Mean Squared Error: 152.61
# ITERATION 39:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 164.4780
# Test Data Mean Squared Error: 168.02
# ITERATION 40:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 216.8336
# Test Data Mean Squared Error: 207.63
# ITERATION 41:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 525.5988
# Test Data Mean Squared Error: 581.68
# ITERATION 42:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 238.0596
# Test Data Mean Squared Error: 248.97
# ITERATION 43:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 460.8654
# Test Data Mean Squared Error: 470.74
# ITERATION 44:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1139.5809
# Test Data Mean Squared Error: 1163.84
# ITERATION 45:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 179.0390
# Test Data Mean Squared Error: 184.43
# ITERATION 46:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 174.7294
# Test Data Mean Squared Error: 178.29
# ITERATION 47:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 414.9476
# Test Data Mean Squared Error: 392.12
# ITERATION 48:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 591.5606
# Test Data Mean Squared Error: 586.37
# ITERATION 49:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 131.6306
# Test Data Mean Squared Error: 150.94
# ITERATIONS COMPLETE
# Test Data Statistics:
# - Mean of the MSEs: 523.77
# - Standard Deviation of the MSEs: 609.71

# %% [markdown]
# ## Part B: Normalize the Data

# %% [markdown]
# Here we scale the predictors to improve model performance.
# - The training data predictors are scaled by subtracting the mean and dividing by the standard deviation.
# - To prevent _data leakeage_, also known as _data snooping_, the test data predictors are scaled in the same way as the training data predictors but using the training data predictors' mean and standard deviation.
# - The scaling is executed using scikit-learn's StandardScaler, which we learned about in the previous course (Machine Learning with Python).
#
# In addition, **because this is a regression problem, the targets are also be scaled**.
# - The training data targets are scaled by subtracting the mean and dividing by the standard deviation.
# - As before, to prevent _data leakage_, the test data targets are scaled using the training data targets' mean and standard deviation.
# - Again, we use Scikit-learn's StandardScaler.
# - After prediction, the model outputs are inverse-scaled (i.e., inverse-transformed) so that the final outputs are mapped to their original scale. This is important because it allows us to compare the results of Parts A and B.

# %%
# Wrap the code in a function for use in Parts B, C & D
def build_train_test_with_normalization( epochs) :
    # Initialize number of iterations and MSEs placeholder
    iterations = 50
    mses       = np.zeros((iterations,))
    # Iterate...
    for i in range(iterations) :
        print(f'ITERATION {i}:')
        # Split data into training and test sets
        X_train, X_test, y_train, y_test = split_data( test_size = 0.30)
        # Reshape targets
        y_train = y_train.reshape(-1,1)
        y_test  = y_test.reshape(-1,1)
        # Initialize and fit training data scalers
        scaler_X = StandardScaler()
        scaler_y = StandardScaler()
        scaler_X.fit(X_train)
        scaler_y.fit(y_train)
        # Scale the training and test data
        X_train_scaled = scaler_X.transform(X_train)
        y_train_scaled = scaler_y.transform(y_train)
        X_test_scaled  = scaler_X.transform(X_test)
        y_test_scaled  = scaler_y.transform(y_test)
        # Build and train neural network model
        model = regression_model()
        model.fit( X_train_scaled,
                   y_train_scaled, epochs = epochs, verbose = 0)
        # Compute scaled predictions
        y_pred_scaled = model.predict(X_test_scaled)
        # Inverse scale predictions
        y_pred = scaler_y.inverse_transform(y_pred_scaled)
        # Compute the Mean Squared Error (MSE)
        mses[i] = mean_squared_error( y_test, y_pred)
        print(f'Test Data Mean Squared Error: {mses[i]:.2f}')
    # Compute and report the mean and std of the MSEs
    print('ITERATIONS COMPLETE')
    mses_mean = mses.mean()
    mses_std  = mses.std()
    print('Test Data Statistics:')
    print(f'- Mean of the MSEs: {mses_mean:.2f}')
    print(f'- Standard Deviation of the MSEs: {mses_std:.2f}')
    return

# %%
build_train_test_with_normalization( epochs = 50)
# Out:
# ITERATION 0:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Test Data Mean Squared Error: 168.15
# ITERATION 1:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Test Data Mean Squared Error: 152.56
# ITERATION 2:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Test Data Mean Squared Error: 159.64
# ITERATION 3:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Test Data Mean Squared Error: 147.22
# ITERATION 4:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Test Data Mean Squared Error: 161.63
# ITERATION 5:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Test Data Mean Squared Error: 148.86
# ITERATION 6:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Test Data Mean Squared Error: 146.24
# ITERATION 7:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Test Data Mean Squared Error: 156.35
# ITERATION 8:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Test Data Mean Squared Error: 149.47
# ITERATION 9:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Test Data Mean Squared Error: 146.35
# ITERATION 10:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Test Data Mean Squared Error: 143.62
# ITERATION 11:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Test Data Mean Squared Error: 154.56
# ITERATION 12:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Test Data Mean Squared Error: 161.05
# ITERATION 13:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Test Data Mean Squared Error: 137.76
# ITERATION 14:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Test Data Mean Squared Error: 142.21
# ITERATION 15:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Test Data Mean Squared Error: 169.75
# ITERATION 16:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Test Data Mean Squared Error: 143.48
# ITERATION 17:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Test Data Mean Squared Error: 140.26
# ITERATION 18:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Test Data Mean Squared Error: 148.55
# ITERATION 19:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Test Data Mean Squared Error: 134.38
# ITERATION 20:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Test Data Mean Squared Error: 159.42
# ITERATION 21:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Test Data Mean Squared Error: 161.60
# ITERATION 22:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Test Data Mean Squared Error: 155.86
# ITERATION 23:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Test Data Mean Squared Error: 131.51
# ITERATION 24:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Test Data Mean Squared Error: 148.80
# ITERATION 25:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Test Data Mean Squared Error: 129.85
# ITERATION 26:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Test Data Mean Squared Error: 153.34
# ITERATION 27:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Test Data Mean Squared Error: 144.83
# ITERATION 28:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Test Data Mean Squared Error: 149.02
# ITERATION 29:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Test Data Mean Squared Error: 143.71
# ITERATION 30:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Test Data Mean Squared Error: 144.97
# ITERATION 31:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Test Data Mean Squared Error: 144.08
# ITERATION 32:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Test Data Mean Squared Error: 141.15
# ITERATION 33:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Test Data Mean Squared Error: 128.77
# ITERATION 34:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Test Data Mean Squared Error: 161.48
# ITERATION 35:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Test Data Mean Squared Error: 163.58
# ITERATION 36:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Test Data Mean Squared Error: 161.62
# ITERATION 37:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Test Data Mean Squared Error: 153.91
# ITERATION 38:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Test Data Mean Squared Error: 161.26
# ITERATION 39:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Test Data Mean Squared Error: 149.07
# ITERATION 40:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Test Data Mean Squared Error: 163.15
# ITERATION 41:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Test Data Mean Squared Error: 123.98
# ITERATION 42:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Test Data Mean Squared Error: 127.66
# ITERATION 43:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Test Data Mean Squared Error: 135.79
# ITERATION 44:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Test Data Mean Squared Error: 137.17
# ITERATION 45:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Test Data Mean Squared Error: 160.24
# ITERATION 46:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Test Data Mean Squared Error: 152.74
# ITERATION 47:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Test Data Mean Squared Error: 141.80
# ITERATION 48:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Test Data Mean Squared Error: 146.61
# ITERATION 49:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Test Data Mean Squared Error: 142.72
# ITERATIONS COMPLETE
# Test Data Statistics:
# - Mean of the MSEs: 148.64
# - Standard Deviation of the MSEs: 10.90

# %% [markdown]
# **How does the mean of the mean squared errors compare to that from Part A?**
# - The mean of the MSEs has decreased significantly.
#   - Part A mean MSE: 523.77
#   - Part B mean MSE: 148.64
#   - Percentage decrease: 71.62%
# - The standard deviation has also decreased even more significantly.
#   - Part A mean STD: 609.71
#   - Part B mean STD: 10.90
#   - Percentage decrease: 98.21%
# - The lesson is: Data normalization significantly improves model performance.

# %% [markdown]
# # Part C: Increase the Number of Epochs

# %% [markdown]
# Here we re-run the code from Part B with 100 epochs.

# %%
build_train_test_with_normalization( epochs = 100)
# Out:
# ITERATION 0:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Test Data Mean Squared Error: 134.52
# ITERATION 1:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Test Data Mean Squared Error: 149.62
# ITERATION 2:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Test Data Mean Squared Error: 128.98
# ITERATION 3:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Test Data Mean Squared Error: 128.65
# ITERATION 4:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Test Data Mean Squared Error: 140.65
# ITERATION 5:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Test Data Mean Squared Error: 138.42
# ITERATION 6:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Test Data Mean Squared Error: 144.49
# ITERATION 7:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Test Data Mean Squared Error: 144.57
# ITERATION 8:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Test Data Mean Squared Error: 135.81
# ITERATION 9:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Test Data Mean Squared Error: 140.94
# ITERATION 10:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Test Data Mean Squared Error: 149.92
# ITERATION 11:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Test Data Mean Squared Error: 136.78
# ITERATION 12:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Test Data Mean Squared Error: 137.25
# ITERATION 13:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Test Data Mean Squared Error: 132.32
# ITERATION 14:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Test Data Mean Squared Error: 150.95
# ITERATION 15:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Test Data Mean Squared Error: 136.78
# ITERATION 16:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Test Data Mean Squared Error: 144.26
# ITERATION 17:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Test Data Mean Squared Error: 146.87
# ITERATION 18:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Test Data Mean Squared Error: 140.46
# ITERATION 19:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Test Data Mean Squared Error: 140.68
# ITERATION 20:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Test Data Mean Squared Error: 141.66
# ITERATION 21:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Test Data Mean Squared Error: 137.05
# ITERATION 22:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Test Data Mean Squared Error: 131.16
# ITERATION 23:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Test Data Mean Squared Error: 126.13
# ITERATION 24:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Test Data Mean Squared Error: 130.76
# ITERATION 25:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Test Data Mean Squared Error: 137.07
# ITERATION 26:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Test Data Mean Squared Error: 139.67
# ITERATION 27:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Test Data Mean Squared Error: 144.54
# ITERATION 28:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Test Data Mean Squared Error: 131.91
# ITERATION 29:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Test Data Mean Squared Error: 149.73
# ITERATION 30:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Test Data Mean Squared Error: 134.45
# ITERATION 31:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Test Data Mean Squared Error: 127.35
# ITERATION 32:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Test Data Mean Squared Error: 143.17
# ITERATION 33:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Test Data Mean Squared Error: 131.42
# ITERATION 34:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Test Data Mean Squared Error: 141.48
# ITERATION 35:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Test Data Mean Squared Error: 132.90
# ITERATION 36:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Test Data Mean Squared Error: 137.30
# ITERATION 37:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Test Data Mean Squared Error: 160.46
# ITERATION 38:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Test Data Mean Squared Error: 143.18
# ITERATION 39:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Test Data Mean Squared Error: 143.57
# ITERATION 40:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Test Data Mean Squared Error: 146.83
# ITERATION 41:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Test Data Mean Squared Error: 159.12
# ITERATION 42:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Test Data Mean Squared Error: 153.55
# ITERATION 43:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Test Data Mean Squared Error: 149.06
# ITERATION 44:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Test Data Mean Squared Error: 142.92
# ITERATION 45:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Test Data Mean Squared Error: 138.26
# ITERATION 46:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Test Data Mean Squared Error: 149.29
# ITERATION 47:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Test Data Mean Squared Error: 157.29
# ITERATION 48:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Test Data Mean Squared Error: 141.28
# ITERATION 49:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Test Data Mean Squared Error: 150.01
# ITERATIONS COMPLETE
# Test Data Statistics:
# - Mean of the MSEs: 141.11
# - Standard Deviation of the MSEs: 8.07

# %% [markdown]
# **How does the mean of the mean squared errors compare to that from Part B?**
# - The mean of the MSEs has decreased.
#   - Part B mean MSE: 148.64
#   - Part C mean MSE: 141.11
#   - Percentage decrease: 5.07%
# - The standard deviation has also decreased.
#   - Part B mean STD: 10.90
#   - Part C mean STD: 8.07
#   - Percentage decrease: 25.96%
# - The lesson is: In this particular case, i.e., for this dataset and for this _shallow_ neural network model (1 hidden layer), more training epochs lead to better model performance.

# %% [markdown]
# ## Part D: Increase the Number of Hidden Layers

# %% [markdown]
# As instructed, we build a neural network model with the following specifications:
# - Three hidden layers, each with 10 nodes with ReLU activations.
# - Optimizer: Adam (short for Adaptive Momentum)
# - Loss: Mean Squared Error

# %%
# Re-define neural network model
del regression_model
def regression_model() :
    model = Sequential()
    model.add( Input( shape = (n_cols,)) )
    model.add( Dense( 10, activation = 'relu') )
    model.add( Dense( 10, activation = 'relu') )
    model.add( Dense( 10, activation = 'relu') )
    model.add( Dense(1) )
    model.compile( optimizer = 'adam', loss = 'mean_squared_error')
    return model

# %% [markdown]
# With the neural network model re-defined, we can re-run the code from Part B.

# %%
build_train_test_with_normalization( epochs = 50)
# Out:
# ITERATION 0:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Test Data Mean Squared Error: 128.67
# ITERATION 1:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Test Data Mean Squared Error: 145.59
# ITERATION 2:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Test Data Mean Squared Error: 132.06
# ITERATION 3:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Test Data Mean Squared Error: 145.31
# ITERATION 4:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Test Data Mean Squared Error: 138.45
# ITERATION 5:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Test Data Mean Squared Error: 149.23
# ITERATION 6:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Test Data Mean Squared Error: 142.27
# ITERATION 7:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Test Data Mean Squared Error: 144.37
# ITERATION 8:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Test Data Mean Squared Error: 140.71
# ITERATION 9:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Test Data Mean Squared Error: 138.96
# ITERATION 10:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Test Data Mean Squared Error: 148.41
# ITERATION 11:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Test Data Mean Squared Error: 140.04
# ITERATION 12:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Test Data Mean Squared Error: 147.95
# ITERATION 13:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Test Data Mean Squared Error: 150.17
# ITERATION 14:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Test Data Mean Squared Error: 151.93
# ITERATION 15:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Test Data Mean Squared Error: 160.67
# ITERATION 16:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Test Data Mean Squared Error: 161.40
# ITERATION 17:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Test Data Mean Squared Error: 149.25
# ITERATION 18:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Test Data Mean Squared Error: 137.68
# ITERATION 19:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Test Data Mean Squared Error: 142.05
# ITERATION 20:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Test Data Mean Squared Error: 132.06
# ITERATION 21:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Test Data Mean Squared Error: 147.90
# ITERATION 22:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Test Data Mean Squared Error: 145.34
# ITERATION 23:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Test Data Mean Squared Error: 140.81
# ITERATION 24:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Test Data Mean Squared Error: 128.43
# ITERATION 25:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Test Data Mean Squared Error: 149.44
# ITERATION 26:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Test Data Mean Squared Error: 133.22
# ITERATION 27:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Test Data Mean Squared Error: 138.35
# ITERATION 28:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Test Data Mean Squared Error: 139.29
# ITERATION 29:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Test Data Mean Squared Error: 146.26
# ITERATION 30:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Test Data Mean Squared Error: 153.47
# ITERATION 31:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Test Data Mean Squared Error: 143.38
# ITERATION 32:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Test Data Mean Squared Error: 143.82
# ITERATION 33:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Test Data Mean Squared Error: 130.20
# ITERATION 34:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Test Data Mean Squared Error: 149.82
# ITERATION 35:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Test Data Mean Squared Error: 145.67
# ITERATION 36:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Test Data Mean Squared Error: 145.27
# ITERATION 37:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Test Data Mean Squared Error: 125.44
# ITERATION 38:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Test Data Mean Squared Error: 155.72
# ITERATION 39:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Test Data Mean Squared Error: 146.22
# ITERATION 40:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Test Data Mean Squared Error: 148.22
# ITERATION 41:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Test Data Mean Squared Error: 134.80
# ITERATION 42:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Test Data Mean Squared Error: 135.32
# ITERATION 43:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Test Data Mean Squared Error: 164.85
# ITERATION 44:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Test Data Mean Squared Error: 137.11
# ITERATION 45:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Test Data Mean Squared Error: 131.63
# ITERATION 46:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Test Data Mean Squared Error: 132.20
# ITERATION 47:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Test Data Mean Squared Error: 137.70
# ITERATION 48:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Test Data Mean Squared Error: 161.33
# ITERATION 49:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Test Data Mean Squared Error: 151.93
# ITERATIONS COMPLETE
# Test Data Statistics:
# - Mean of the MSEs: 143.41
# - Standard Deviation of the MSEs: 8.99

# %% [markdown]
# **How does the mean of the mean squared errors compare to that from Part B?**
# - The mean of the MSEs has decreased.
#   - Part B mean MSE: 148.64
#   - Part C mean MSE: 143.41
#   - Percentage decrease: 3.52%
# - The standard deviation has also decreased.
#   - Part B mean STD: 10.90
#   - Part C mean STD: 8.99
#   - Percentage decrease: 17.52%
# - However, the model performed better in Part C than in Part D. This may be due to overfitting. The lesson is: In this particular case, i.e., for this dataset and this _deep_ neural network model (3 hidden layers), adding too many extra hidden layers excessively increases model complexity and thus might lead to overfitting.
